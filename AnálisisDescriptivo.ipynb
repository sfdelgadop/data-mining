# %%
import pandas as pd 
import numpy as np
from scipy.stats import trim_mean
from numpy import mean, absolute

# %% [markdown]
# Por alguna razón solo toma los 1000 primeros valores cuán trato de usar la Api que proporciona datoa abiertos, por lo que toca cargar el archivo completo para que tome los 500000 datos

# %%
data = pd.read_json('https://www.datos.gov.co/resource/rnvb-vnyh.json')

# %%
data = pd.read_csv('Saber_11__2020-2.csv')

# %%
data
# Out:
#        ESTU_TIPODOCUMENTO  ...         ESTU_GENERACION-E
# 0                      TI  ...                        NO
# 1                     PEP  ...                        NO
# 2                      TI  ...  GENERACION E - GRATUIDAD
# 3                      CE  ...                        NO
# 4                      TI  ...                        NO
# ...                   ...  ...                       ...
# 504867                 TI  ...                        NO
# 504868                 CC  ...                        NO
# 504869                 TI  ...                        NO
# 504870                 TI  ...                        NO
# 504871                 TI  ...  GENERACION E - GRATUIDAD
#
# [504872 rows x 81 columns]

# %%
data.head
# Out:
# <bound method NDFrame.head of        ESTU_TIPODOCUMENTO  ...         ESTU_GENERACION-E
# 0                      TI  ...                        NO
# 1                     PEP  ...                        NO
# 2                      TI  ...  GENERACION E - GRATUIDAD
# 3                      CE  ...                        NO
# 4                      TI  ...                        NO
# ...                   ...  ...                       ...
# 504867                 TI  ...                        NO
# 504868                 CC  ...                        NO
# 504869                 TI  ...                        NO
# 504870                 TI  ...                        NO
# 504871                 TI  ...  GENERACION E - GRATUIDAD
#
# [504872 rows x 81 columns]>

# %%
data.groupby('FAMI_ESTRATOVIVIENDA').size()
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 1      152852
# Estrato 2      182322
# Estrato 3      103550
# Estrato 4       23463
# Estrato 5        7019
# Estrato 6        3083
# Sin Estrato     15631
# dtype: int64

# %%
data.groupby('ESTU_DEPTO_RESIDE').size()
# Out:
# ESTU_DEPTO_RESIDE
# AMAZONAS             638
# ANTIOQUIA          70478
# ARAUCA              2989
# ATLANTICO          28590
# BOGOTÁ             77344
# BOLIVAR            24182
# BOYACA             15258
# CALDAS              9951
# CAQUETA             3868
# CASANARE            5501
# CAUCA              12504
# CESAR              12515
# CHOCO               4320
# CORDOBA            19449
# CUNDINAMARCA       33656
# EXTRANJERO            19
# GUAINIA              283
# GUAVIARE             813
# HUILA              12159
# LA GUAJIRA          7950
# MAGDALENA          15264
# META               11655
# NARIÑO             15422
# NORTE SANTANDER    14719
# PUTUMAYO            3652
# QUINDIO             5810
# RISARALDA           9238
# SAN ANDRES           593
# SANTANDER          23766
# SUCRE              10208
# TOLIMA             15796
# VALLE              35442
# VAUPES               322
# VICHADA              516
# dtype: int64

# %%
data.groupby('COLE_NATURALEZA').size()
# Out:
# COLE_NATURALEZA
# NO OFICIAL    113402
# OFICIAL       391470
# dtype: int64

# %%
data.groupby('COLE_AREA_UBICACION').size()
# Out:
# COLE_AREA_UBICACION
# RURAL      82894
# URBANO    421978
# dtype: int64

# %%
print(data['PUNT_GLOBAL'].mean())
print(data['PUNT_INGLES'].mean())
print(data['PUNT_SOCIALES_CIUDADANAS'].mean())
print(data['PUNT_C_NATURALES'].mean())
print(data['PUNT_MATEMATICAS'].mean())
print(data['PUNT_LECTURA_CRITICA'].mean())
# Out:
# 248.34710183967422
# 46.88350728785542
# 48.23393850322458
# 48.197372799442235
# 51.019753521684706
# 52.156784293840815

# %%
print(data['PUNT_GLOBAL'].median())
print(data['PUNT_INGLES'].median())
print(data['PUNT_SOCIALES_CIUDADANAS'].median())
print(data['PUNT_C_NATURALES'].median())
print(data['PUNT_MATEMATICAS'].median())
print(data['PUNT_LECTURA_CRITICA'].median())
# Out:
# 245.0
# 45.0
# 47.0
# 48.0
# 51.0
# 52.0

# %%
for i in np.arange(0, 1.25, 0.25):
    print(i,"%:",data['PUNT_GLOBAL'].quantile(i))
# Out:
# 0.0 %: 0.0
# 0.25 %: 211.0
# 0.5 %: 245.0
# 0.75 %: 282.0
# 1.0 %: 500.0

# %%
data['PUNT_GLOBAL'].std()
# Out:
# 48.69252341120044

# %% [markdown]
# En la siguiente celda se haya el coeficiente de correlación de pearson, hay muchos datos que python toma como númericos y trata de sacarles la correlación pero no tienen mucho sentido hacerso así sin más, en futuras fases del proyecto se corregirá esto

# %%
data.corr()
# Out:
#                                PERIODO  ...  ESTU_NSE_ESTABLECIMIENTO
# PERIODO                            NaN  ...                       NaN
# ESTU_COD_RESIDE_DEPTO              NaN  ...                 -0.009883
# ESTU_COD_RESIDE_MCPIO              NaN  ...                 -0.175196
# COLE_CODIGO_ICFES                  NaN  ...                 -0.144278
# COLE_COD_DANE_ESTABLECIMIENTO      NaN  ...                  0.215153
# COLE_COD_DANE_SEDE                 NaN  ...                  0.208043
# COLE_COD_MCPIO_UBICACION           NaN  ...                 -0.174313
# COLE_COD_DEPTO_UBICACION           NaN  ...                 -0.170984
# ESTU_COD_MCPIO_PRESENTACION        NaN  ...                 -0.174624
# ESTU_COD_DEPTO_PRESENTACION        NaN  ...                 -0.171569
# PUNT_LECTURA_CRITICA               NaN  ...                  0.387720
# PERCENTIL_LECTURA_CRITICA          NaN  ...                  0.387936
# ...

# %% [markdown]
# Un comentario similar al anterior, hay algunos datos que no tienen mucho sentido sacarles ciertas medidas al ser categoricos numéricos, pero en futuras fases se filtrarán y solo se tomarán aquellos que tenga sentido usar para el análisis

# %%
data.describe(include='all')
# Out:
#        ESTU_TIPODOCUMENTO  ... ESTU_GENERACION-E
# count              504872  ...            504872
# unique                 11  ...                 4
# top                    TI  ...                NO
# freq               413514  ...            255839
# mean                  NaN  ...               NaN
# std                   NaN  ...               NaN
# min                   NaN  ...               NaN
# 25%                   NaN  ...               NaN
# 50%                   NaN  ...               NaN
# 75%                   NaN  ...               NaN
# max                   NaN  ...               NaN
#
# [11 rows x 81 columns]

# %%
hist = data['PUNT_GLOBAL'].hist(bins=250)

# %% [markdown]
# Ya se puede ver que los puntajes globales se organizan en una función normal

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize = (170, 27)) 
data.boxplot()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
